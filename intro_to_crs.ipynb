# %%
import os 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import seaborn as sns
import geopandas as gpd
from shapely.geometry import Point
import earthpy as et

# %%
sns.set(font_scale=1.5)
sns.set_style("white")

# %%
data = et.data.get_data('spatial-vector-lidar')
os.chdir(os.path.join(et.io.HOME, 'earth-analytics'))
# Out:
# Downloading from https://ndownloader.figshare.com/files/12459464
# Extracted output to /home/codespace/earth-analytics/data/spatial-vector-lidar/.

# %%
worldBound_path = os.path.join("data", "spatial-vector-lidar", "global", "ne_110m_land", "ne_110m_land.shp")
worldBound = gpd.read_file(worldBound_path)

worldBound.head()
# Out:
#   featurecla  scalerank                                           geometry
# 0    Country          1  POLYGON ((-59.57209 -80.04018, -59.86585 -80.5...
# 1    Country          1  POLYGON ((-159.20818 -79.49706, -161.12760 -79...
# 2    Country          1  POLYGON ((-45.15476 -78.04707, -43.92083 -78.4...
# 3    Country          1  POLYGON ((-121.21151 -73.50099, -119.91885 -73...
# 4    Country          1  POLYGON ((-125.55957 -73.48135, -124.03188 -73...

# %%
fig, ax = plt.subplots(figsize=(10, 5))
worldBound.plot(color='teal', ax=ax)

ax.set(xlabel="Longitude (Degrees)", ylabel="Latitude (Degrees)", title="Global Map - Geographic Coordinate System - WGS84 Datum\n Units: Degrees - Latitude / Longitude")


ax.set_axisbelow(True)
ax.yaxis.grid(color='maroon', linestyle='dashed')
ax.xaxis.grid(color='cyan',   linestyle='dashed')

plt.show()

# %%
add_points = np.array([[-105.2519,   40.0274], 
                       [-118.1937,   40.0274], 
                       [-115.9010,   33.8734]])

city_locations = [Point(xy)for xy in add_points]
city_locations
# Out:
# [<POINT (-105.252 40.027)>,
#  <POINT (-118.194 40.027)>,
#  <POINT (-115.901 33.873)>]

# %%
city_locations = gpd.GeoDataFrame(city_locations, columns=["geometry"], crs=worldBound.crs)
city_locations
# Out:
#                       geometry
# 0  POINT (-105.25190 40.02740)
# 1  POINT (-118.19370 40.02740)
# 2  POINT (-115.90100 33.87340)

# %%
fig, ax = plt.subplots(figsize=(12, 8))

worldBound.plot(figsize=(10, 5), color='k',
               ax=ax)

city_locations.plot(ax=ax, 
                    color='springgreen', 
                    marker='*',
                    markersize=45)


ax.set(xlabel="Longitude (Degrees)", ylabel="Latitude (Degrees)",
       title="Global Map - Geographic Coordinate System - WGS84 Datum\n Units: Degrees - Latitude / Longitude")
ax.set_axisbelow(True)
ax.yaxis.grid(color='gray', linestyle='dashed')
ax.xaxis.grid(color='gray', linestyle='dashed')

# %%
graticule_path = os.path.join("data", "spatial-vector-lidar", "global", 
                              "ne_110m_graticules_all", "ne_110m_graticules_15.shp")
graticule = gpd.read_file(graticule_path)

bbox_path = os.path.join("data", "spatial-vector-lidar", "global", 
                         "ne_110m_graticules_all", "ne_110m_wgs84_bounding_box.shp")
bbox = gpd.read_file(bbox_path)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 8))

bbox.plot(ax=ax, alpha=.1, color='purple')
graticule.plot(ax=ax, color='pink')
worldBound.plot(ax=ax, color='cyan')

city_locations.plot(ax=ax, markersize=60, color='teal', marker='*')

ax.set(title="World Map - Geographic Coordinate Reference System (long/lat degrees)", xlabel="X Coordinates (meters)", ylabel="Y Coordinates (meters)");
plt.show()

# %%
worldBound_robin = worldBound.to_crs("+proj=robin")
graticule_robin = graticule.to_crs("+proj=robin")

# %%
fig, ax = plt.subplots(figsize=(12,8))

worldBound_robin.plot(ax=ax, color="blue")

graticule_robin.plot(ax=ax, color="yellow")

ax.set(title="World Map Robinson", xlabel="X coords - Meters", ylabel="Y coords - Meters")

for axis in [ax.xaxis, ax.yaxis]:
    formatter = ScalarFormatter()
    formatter.set_scientific(False)
    axis.set_major_formatter(formatter)

# %%
fig, ax = plt.subplots(figsize=(12,8))

worldBound_robin.plot(ax=ax, color="blue")

graticule_robin.plot(ax=ax, color="yellow")

city_locations.plot(ax=ax, marker="*", markersize=150, color="black")

ax.set(title="World Map Robinson", xlabel="X coords - Meters", ylabel="Y coords - Meters")

for axis in [ax.xaxis, ax.yaxis]:
    formatter = ScalarFormatter()
    formatter.set_scientific(False)
    axis.set_major_formatter(formatter)

    plt.axis("equal")
    plt.show()

# %%
city_locations_robin = city_locations.to_crs(worldBound_robin.crs)

fig, ax = plt.subplots(figsize=(12,8))

worldBound_robin.plot(ax=ax, color="blue")

graticule_robin.plot(ax=ax, color="yellow")

city_locations_robin.plot(ax=ax, marker="*", markersize=150, color="red")

ax.set(title="World Map Robinson", xlabel="X coords - Meters", ylabel="Y coords - Meters")

for axis in [ax.xaxis, ax.yaxis]:
    formatter = ScalarFormatter()
    formatter.set_scientific(False)
    axis.set_major_formatter(formatter)

    plt.axis("equal")
    plt.show()

# %%
graticule_robinson = graticule.to_crs("+proj=robin")
bbox_robinson = bbox.to_crs("+proj=robin")

fig, (ax0, ax1) = plt.subplots(2, 1, figsize=(13, 12))

# Plot 1

bbox.plot(ax=ax0, alpha=0.1, color="grey")
graticule.plot(ax=ax0,
               color='lightgrey')
worldBound.plot(ax=ax0, markersize=150, color="green")
ax0.set(title="World Map - Geographic (long/lat degrees)")

# plot 2

bbox_robinson.plot(ax=ax1, alpha=.1, color='grey')
graticule_robinson.plot(ax=ax1, color='lightgrey')
worldBound_robin.plot(ax=ax1, color='k')
city_locations_robin.plot(ax=ax1, markersize=100, color='springgreen')
ax1.set(title="World Map Projected - Robinson (Meters)")

for axis in [ax1.xaxis, ax1.yaxis]:
    formatter = ScalarFormatter()
    formatter.set_scientific(False)
    axis.set_major_formatter(formatter)

plt.show()
